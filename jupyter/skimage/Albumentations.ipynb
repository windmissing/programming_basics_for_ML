# %% [markdown]
# # 随机剪裁

# %%
import cv2
from matplotlib import pyplot as plt
image = cv2.imread("file/000040d66f14ced4cdd18cd95d91800f.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
from albumentations import Compose, RandomResizedCrop
compose = Compose([RandomResizedCrop(100, 100)])  # 剪裁大小为100*100
image = compose(image=image)['image']
plt.imshow(image)

# %% [markdown]
# # 图像缩放

# %%
import cv2
from matplotlib import pyplot as plt
image = cv2.imread("file/000040d66f14ced4cdd18cd95d91800f.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
from albumentations import Compose, Resize
compose = Compose([Resize(100, 100)])  # 缩放大小为100*100
image = compose(image=image)['image']
plt.imshow(image)

# %% [markdown]
# # 像素归一化

# %%
import cv2
from matplotlib import pyplot as plt
image = cv2.imread("file/000040d66f14ced4cdd18cd95d91800f.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
from albumentations import Compose, Normalize
compose = Compose([Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            )])  # 缩放大小为100*100
image = compose(image=image)['image']
plt.imshow(image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 转换为pytorch.tensor类型

# %%
import cv2
from matplotlib import pyplot as plt
image = cv2.imread("file/000040d66f14ced4cdd18cd95d91800f.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print (type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
from albumentations import Compose
from albumentations.pytorch import ToTensorV2
compose = Compose([ToTensorV2()])   # conda install Cython
image = compose(image=image)['image']
print (type(image))
# Out:
# <class 'torch.Tensor'>
