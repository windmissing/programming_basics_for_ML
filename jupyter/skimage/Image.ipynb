# %% [markdown]
# # 读入图像并显示

# %%
from PIL import Image
img = Image.open("file/COCO_val2014_000000000042.jpg")
plt.imshow(img)

# %% [markdown]
# # 改变图像大小

# %%
img2 = img.resize((50, 100), Image.BILINEAR)
plt.imshow(img2)

# %%
img2
# Out:
# <PIL.Image.Image image mode=RGB size=50x50 at 0x19CB5FA9A20>

# %% [markdown]
# # 图像转numpy

# %%
img_array = np.array(img) 
img_array.shape
# Out:
# (478, 640, 3)

# %%
img_array = np.array(img2) 
img_array.shape
# Out:
# (50, 50, 3)
