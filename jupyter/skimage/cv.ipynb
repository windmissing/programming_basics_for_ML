# %% [markdown]
# ```
# pip install opencv-python
# ```

# %% [markdown]
# # 读入图像并显示

# %%
import cv2
image = cv2.imread("file/000040d66f14ced4cdd18cd95d91800f.png")
cv2.imshow('image',image)
cv2.waitKey()
cv2.destroyAllWindows() # important part!否则会出现退出时卡死的问题

# %%
import cv2
from matplotlib import pyplot as plt
image = cv2.imread("file/000040d66f14ced4cdd18cd95d91800f.png")
plt.imshow(image)# opencv的通道顺序与matplotlib不同，所以看上去有色差

# %%
import cv2
from matplotlib import pyplot as plt
image = cv2.imread("file/000040d66f14ced4cdd18cd95d91800f.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)    # 转移成matplotlib的通道顺序，就能看到正常的图像
plt.imshow(image)
