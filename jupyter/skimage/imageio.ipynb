# %% [markdown]
# # 读入图像

# %%
import imageio
from matplotlib.pyplot import imshow

image = imageio.imread("file/000040d66f14ced4cdd18cd95d91800f.png")
imshow(image)

# %% [markdown]
# # 显示图像大小

# %%
image.size
# Out:
# 337500

# %%
image.shape
# Out:
# (300, 375, 3)

# %% [markdown]
# # 图像缩放

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-1159ad16be86> in <module>
# ----> 1 image.resize(100, 100, 3)
#
# ValueError: cannot resize this array: it does not own its data

# %%
imageio?
